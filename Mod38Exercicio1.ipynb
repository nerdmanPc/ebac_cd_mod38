# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Módulo 37

# %% [markdown]
# # Tarefa II
#
# Neste projeto, estamos construindo um credit scoring para cartão de crédito, em um desenho amostral com 15 safras, e utilizando 12 meses de performance.
#
# Carregue a base de dados ```credit_scoring.ftr```.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_feather('credit_scoring.ftr')
df.head()
# Out:
#     data_ref  index sexo posse_de_veiculo posse_de_imovel  qtd_filhos  \
# 0 2015-01-01   5733    F                N               N           0
# 1 2015-01-01    727    F                S               S           0
# 2 2015-01-01   6374    F                N               N           2
# 3 2015-01-01   9566    F                N               N           0
# 4 2015-01-01   9502    F                S               N           0
#
#     tipo_renda             educacao estado_civil tipo_residencia  idade  \
# 0   Empresário                Médio     Solteiro            Casa     43
# 1  Assalariado                Médio       Casado            Casa     35
# 2  Assalariado                Médio       Casado            Casa     31
# 3  Assalariado                Médio       Casado            Casa     54
# 4  Assalariado  Superior incompleto     Solteiro            Casa     31
#
#    tempo_emprego  qt_pessoas_residencia     renda    mau
# 0       6.873973                    1.0   2515.39  False
# 1       4.526027                    2.0   3180.19  False
# 2       0.243836                    4.0   1582.29  False
# 3      12.772603                    2.0  13721.17  False
# 4       8.432877                    1.0   2891.08  False

# %% [markdown]
# ## Amostragem
#
# Separe os três últimos meses como safras de validação *out of time* (oot).
#
# Variáveis:<br>
# Considere que a variável ```data_ref``` não é uma variável explicativa, é somente uma variável indicadora da safra, e não deve ser utilizada na modelagem. A variávei ```index``` é um identificador do cliente, e também não deve ser utilizada como covariável (variável explicativa). As restantes podem ser utilizadas para prever a inadimplência, incluindo a renda.

# %% [markdown]
# Na célula abaixo, sõ feitas três coisas:
# 1. Identificação das safras;
# 2. Remoção das colunas *index* e *data_ref*;
# 3. Substitiução da variével renda pelo seu logarítimo;
#
# Realizamos a transformação do ítem 3 porque ela lineariza uma série de relações e melhora a distribuição da variáveis financeiras, como a renda.

# %%
df['safra'] = (df['data_ref'].dt.year - min(df['data_ref'].dt.year))*12 + df['data_ref'].dt.month
df.drop(inplace=True, columns=['index', 'data_ref'], errors='ignore')
df['renda'] = np.log(df.renda)
#df

# %% [markdown]
# Agora, separamos os dados em treino (df) e teste (df_teste)

# %%
df_test = df[df.safra > 12].copy()
#df_test
df = df[df.safra <= 12].copy()
#df

# %% [markdown]
# Aqui, criamos o *dataframe* de metadados das variáveis com as segintes colunas:
# 1. Tipo de dados - *dtype*
# 1. Número de registros nulos - *n_missing*
# 1. Número de valores únicos - *n_unique*
# 1. Indicador se a variável é numérica - *numeric*
# 1. Tipo da variável (covarável, temporal ou resposta) - *role*

# %%
metadados = pd.DataFrame(df.dtypes, columns=['dtype'])
metadados['n_missing'] = df.isna().sum()
metadados['n_unique'] = df.nunique()
metadados['numeric'] = (metadados.dtype == 'int64') | (metadados.dtype == 'float64')
metadados['role'] = 'covariavel'
metadados.loc['mau', 'role'] = 'resposta'
metadados.loc['safra', 'role'] = 'temporal'
metadados
# Out:
#                          dtype  n_missing  n_unique  numeric        role
# sexo                    object          0         2    False  covariavel
# posse_de_veiculo        object          0         2    False  covariavel
# posse_de_imovel         object          0         2    False  covariavel
# qtd_filhos               int64          0         8     True  covariavel
# tipo_renda              object          0         5    False  covariavel
# educacao                object          0         5    False  covariavel
# estado_civil            object          0         5    False  covariavel
# tipo_residencia         object          0         6    False  covariavel
# idade                    int64          0        47     True  covariavel
# tempo_emprego          float64     100875      3004     True  covariavel
# qt_pessoas_residencia  float64          0         9     True  covariavel
# renda                  float64          0    112472     True  covariavel
# mau                       bool          0         2    False    resposta
# safra                    int64          0        12     True    temporal

# %% [markdown]
# ## Descritiva básica univariada
#
# - Descreva a base quanto ao número de linhas, número de linhas para cada mês em ```data_ref```.
# - Faça uma descritiva básica univariada de cada variável. Considere as naturezas diferentes: qualitativas e quantitativas.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
sns.histplot(df, x='safra', ax=ax)
ax.set_title('Distribuição dos registros por safra')
# Out:
# Text(0.5, 1.0, 'Distribuição dos registros por safra')

# %% [markdown]
# Como podemos ver, os clientes estão bem distribuidos entre as safras!
#
# Mas como será a distribuição de variáveis? É isso que vamos ver abaixo!

# %%
from math import ceil

vars = metadados.index
n_colunas = 3
n_linhas = ceil(len(vars) / n_colunas)
fig, axs = plt.subplots(n_linhas, n_colunas, figsize=(12*n_colunas, 6*n_linhas))
for var_i, nome_var in enumerate(vars):
    ax_i = var_i // n_colunas
    ax_j = var_i % n_colunas
    if df.iloc[:,var_i].nunique() > 50:
        sns.histplot(df, x=nome_var, ax=axs[ax_i, ax_j])
    else:
        sns.countplot(df, x=nome_var, ax=axs[ax_i, ax_j])

# %% [markdown]
# No geral, as distribuições estão razoáveis. Porém, note que *qtd_filhos* e *qt_pessoas_residencia* possuem alguns outliers que causam problemas na nossa análise se não tratados.
#
# Para isso, optei por limitá-las em 4 e 5, respectivamente. Sendo assim, o maior valor $x$ representa $x$ ou mais pessoas/filhos.

# %%
df['qtd_filhos'] = df.qtd_filhos.clip(upper=4)
df_test['qtd_filhos'] = df_test.qtd_filhos.clip(upper=4)
df['qt_pessoas_residencia'] = df.qt_pessoas_residencia.clip(upper=5)
df_test['qt_pessoas_residencia'] = df_test.qt_pessoas_residencia.clip(upper=5)

# %% [markdown]
# Agora, vamos analisar se a distribuição das variáveis é estável no tempo.

# %%
vars = metadados[(metadados.role != 'temporal')].index
n_colunas = 3
n_linhas = ceil(len(vars) / n_colunas)
fig, axs = plt.subplots(n_linhas, n_colunas, figsize=(12*n_colunas, 6*n_linhas))
for var_i, nome_var in enumerate(vars):
    ax_i = var_i // n_colunas
    ax_j = var_i % n_colunas
    if df.iloc[:,var_i].nunique() > 20:
        sns.lineplot(df, x='safra', y=nome_var, ax=axs[ax_i, ax_j])
    else:
        count = df.groupby([nome_var, 'safra'])['mau'].count()
        count.name = 'count'
        sns.lineplot(
            hue=count.index.get_level_values(nome_var), 
            x=count.index.get_level_values('safra'), 
            y=count, 
            ax=axs[ax_i, ax_j]
        )

# %% [markdown]
# Como podemos ver, duas distribuições variam no tempo:
# 1. Renda: Possui um pico próximo à safra 7, com valores mais baixos no início e fim da amostra.
# 2. Mau: A proporção de bons pagadores acompanha o aumento de renda no meio da amostra.

# %% [markdown]
# ## Descritiva bivariada
#
# Faça uma análise descritiva bivariada de cada variável

# %% [markdown]
# As funções abaixo calculam o Weigth of Evidence (WOE) e Information Value (IV) de uma variável.

# %%
def iv_tab(variavel, resposta):
    tab = pd.crosstab(variavel, resposta, margins=True, margins_name='total')

    rótulo_evento = tab.columns[0]
    rótulo_nao_evento = tab.columns[1]

    tab['pct_evento'] = tab[rótulo_evento]/tab.loc['total',rótulo_evento]
    tab['pct_nao_evento'] = tab[rótulo_nao_evento]/tab.loc['total',rótulo_nao_evento]
    tab['woe'] = np.log(tab.pct_evento/tab.pct_nao_evento)
    tab['iv_parcial'] = (tab.pct_evento - tab.pct_nao_evento)*tab.woe
    return tab

def iv(variavel, resposta):
    return iv_tab(variavel, resposta).iv_parcial.sum()

def woe(variavel, resposta):
    return iv_tab(variavel, resposta).woe.drop('total')

# %% [markdown]
# Com isso, podemos preencher os metadados com a coluna *iv*.

# %%
n_quantis = 50
for nome_var in metadados[metadados.role != 'resposta'].index:
    variavel = df[nome_var]
    if (metadados.loc[nome_var, 'numeric']) and (metadados.loc[nome_var, 'n_unique'] > n_quantis):
        variavel = pd.qcut(variavel, n_quantis, duplicates='drop')
    metadados.loc[nome_var, 'iv'] = iv(variavel, df.mau)
metadados.sort_values('iv', ascending=False)
# Out:
#                          dtype  n_missing  n_unique  numeric        role  \
# renda                  float64          0    112472     True  covariavel
# tempo_emprego          float64     100875      3004     True  covariavel
# safra                    int64          0        12     True    temporal
# idade                    int64          0        47     True  covariavel
# tipo_renda              object          0         5    False  covariavel
# posse_de_imovel         object          0         2    False  covariavel
# educacao                object          0         5    False  covariavel
# tipo_residencia         object          0         6    False  covariavel
# sexo                    object          0         2    False  covariavel
# qt_pessoas_residencia  float64          0         9     True  covariavel
# qtd_filhos               int64          0         8     True  covariavel
# estado_civil            object          0         5    False  covariavel
# posse_de_veiculo        object          0         2    False  covariavel
# mau                       bool          0         2    False    resposta
#
#                              iv
# renda                  1.122822
# tempo_emprego          0.414825
# safra                  0.276492
# idade                  0.025662
# tipo_renda             0.009718
# posse_de_imovel        0.009690
# educacao               0.003690
# tipo_residencia        0.003330
# sexo                   0.002665
# qt_pessoas_residencia  0.002042
# qtd_filhos             0.001323
# estado_civil           0.001305
# posse_de_veiculo       0.000075
# mau                         NaN

# %% [markdown]
# Aqui, criamos um novo conjunto de metatados excluindo as variáveis com iv menor que 0.02. IV's até esse valor são considerados baixos.

# %%
metadados_b = metadados.drop(metadados[(metadados.iv < 0.01)].index).sort_values('iv', ascending=False)
metadados_b
# Out:
#                  dtype  n_missing  n_unique  numeric        role        iv
# renda          float64          0    112472     True  covariavel  1.122822
# tempo_emprego  float64     100875      3004     True  covariavel  0.414825
# safra            int64          0        12     True    temporal  0.276492
# idade            int64          0        47     True  covariavel  0.025662
# mau               bool          0         2    False    resposta       NaN

# %% [markdown]
# Note que o Information Value da variável *safra* é significativo. Isso confirma o que vimos na análise univariada de que a proporção de maus pagadores varia no tempo!
# Vamos lembrar também, que a variável *idade* tem correlação com *tempo_emprego*, que é a principal preditora de *renda* no modelo de previsão desta. Tais caracteristicas indicam que essas variáveis não são úteis para o modelo de classificação de crédito.

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.tick_params(axis='x', labelrotation = 30)
sns.barplot(metadados_b.dropna(), x=metadados_b.dropna().index, y='iv', ax=ax)
ax.set_ylabel('Information Value (IV)')
ax.set_xlabel('Variável')
# Out:
# Text(0.5, 0, 'Variável')

# %% [markdown]
# Agora, vamos analisar o IV das varáveis selecionados por safra. Será que elas são estáveis no tempo?

# %%
# Função para obter os IV de uma safra. Vamos passá-la para a função GroupBy.aggregate() mais adiante.
def get_iv_safra(safra: pd.DataFrame, metadados:pd.DataFrame, n_quantis: int) -> pd.Series:
    covars = [col for col in safra.columns if metadados.loc[col, 'role'] == 'covariavel']
    linha = pd.Series(index=covars, dtype='float64')
    for nome_var in covars:
        variavel = safra[nome_var]
        if (metadados.loc[nome_var, 'numeric']) and (metadados.loc[nome_var, 'n_unique'] > n_quantis):
            variavel = pd.qcut(variavel, n_quantis, duplicates='drop')
        linha.loc[nome_var] = iv(variavel, safra.mau)
    return linha

# %% [markdown]
# Abaixo, criamos um *DataFrame* a partir da base de treino com as covariáveis categorizadas, a safra de cada registro e a variável resposta.

# %%
n_quantis = 10
df_cat = df[list(metadados_b.index)].copy()

for var in metadados_b.index:
    if not (metadados_b.loc[var, 'numeric']) or not (metadados_b.loc[var, 'role'] == 'covariavel'): continue
    bins = pd.qcut(df[var], n_quantis, retbins=True, duplicates='drop')[1]
    df_cat[var] = pd.cut(df_cat[var], bins, duplicates='drop')
    metadados_b.loc[var, 'numeric'] = False

df_cat
# Out:
#                  renda     tempo_emprego  safra         idade    mau
# 0        (7.804, 8.27]    (6.047, 7.458]      1  (40.0, 43.0]  False
# 1        (7.804, 8.27]     (3.63, 4.693]      1  (33.0, 36.0]  False
# 2       (5.087, 7.804]    (0.118, 1.195]      1  (29.0, 33.0]  False
# 3       (9.484, 9.802]  (11.726, 16.545]      1  (51.0, 55.0]  False
# 4        (7.804, 8.27]    (7.458, 9.093]      1  (29.0, 33.0]  False
# ...                ...               ...    ...           ...    ...
# 599995  (9.199, 9.484]  (16.545, 42.907]     12  (43.0, 47.0]  False
# 599996   (8.27, 8.615]     (3.63, 4.693]     12  (29.0, 33.0]  False
# 599997   (8.27, 8.615]               NaN     12  (60.0, 68.0]   True
# 599998   (7.804, 8.27]  (11.726, 16.545]     12  (36.0, 40.0]   True
# 599999   (7.804, 8.27]               NaN     12  (60.0, 68.0]  False
#
# [600000 rows x 5 columns]

# %% [markdown]
# Aqui, criamos uma tabela de IV's por variável e safra. Isso servirá para o próximo gráfico.

# %%
safras = df_cat.groupby('safra')
safras_iv = safras.aggregate(get_iv_safra, metadados_b, n_quantis)
safras_iv.drop(columns='mau', inplace=True)
safras_iv = safras_iv.melt(ignore_index=False).reset_index()
safras_iv.rename(columns={'variable': 'variavel', 'value':'iv'}, inplace=True)
#safras_iv

# %%
fig, ax = plt.subplots(figsize=(16,8))

sns.lineplot(
    data=safras_iv,
    hue='variavel', 
    x='safra', 
    y='iv', 
    ax=ax
)
# Out:
# <Axes: xlabel='safra', ylabel='iv'>

# %% [markdown]
# Como podemos ver acima, o poder preditivo das variáveis não muda significativamente com o tempo! Porém, ainda temos algumas coisas a esclarecer:
# 1. A proporção de maus pagadores muda com o tempo.
# 2. A renda média também varia com o tempo.
# 3. Apesar disso, o poder de previsão da renda é estável.

# %%
woes_renda = {}
for nome, safra in safras:
    woes_renda[nome] = woe(safra.renda, safra.mau)
woes_renda = pd.DataFrame(woes_renda).melt(ignore_index=False).reset_index().rename(columns={'variable': 'safra', 'value': 'woe'})
woes_renda
# Out:
#                 renda  safra       woe
# 0      (5.087, 7.804]      1 -0.770742
# 1       (7.804, 8.27]      1  0.100074
# 2       (8.27, 8.615]      1  0.476161
# 3      (8.615, 8.913]      1  0.850200
# 4      (8.913, 9.199]      1  1.044050
# ..                ...    ...       ...
# 115    (9.199, 9.484]     12  1.133850
# 116    (9.484, 9.802]     12  1.622782
# 117   (9.802, 10.191]     12  1.605892
# 118  (10.191, 10.801]     12  2.399678
# 119  (10.801, 15.223]     12  2.728195
#
# [120 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(16,8))

sns.lineplot(
    data=woes_renda,
    hue='renda', 
    x='safra', 
    y='woe', 
    ax=ax
)
# Out:
# <Axes: xlabel='safra', ylabel='woe'>

# %% [markdown]
# Analisando o gráfico acima, podemos concluir que, para cada safra, as faixas mantém um mesmo desempenho relativo. Porém, justamente onde a renda média é mais alta, o Weight of Evidence de todas as faixas de renda diminui! Minha hipótese é que o que ajuda a prever bons e maus pagadores é renda relativa e não a renda absoluta. Vamos testar essa hipótese em seguida.

# %% [markdown]
# Para avaliar a hipótese acima, primeiro, vamoscriar duas variáveis:
# 1. $renda\_safra = media(renda_i)$ para cada safra $i$
# 2. $delta\_renda = renda - renda\_safra$

# %%
renda_safra = df.groupby('safra')['renda'].mean()
df['renda_safra'] = df.safra.map(renda_safra)
df['delta_renda'] = df.renda - df.renda_safra
#df

# %%
renda_safra = df_test.groupby('safra')['renda'].mean()
df_test['renda_safra'] = df_test.safra.map(renda_safra)
df_test['delta_renda'] = df_test.renda - df_test.renda_safra
#df_test

# %%
n_quantis = 20
delta_renda_cat = pd.qcut(df.delta_renda, n_quantis, duplicates='drop')
iv = {
    'renda_safra': iv(df.renda_safra, df.mau),
    'delta_renda': iv(delta_renda_cat, df.mau)
}
iv = pd.Series(iv)

# %%
iv
# Out:
# renda_safra    0.276492
# delta_renda    0.800145
# dtype: float64

# %% [markdown]
# Na verdade, as duas componentes da veriável *renda* são importantes!
#
# Porém, separá-las permite ao nosso modelo distinguir caso haja uma diferença de peso entre clientes ricos e pobres versus períodos de maior ou menor renda.

# %% [markdown]
# ## Desenvolvimento do modelo
#
# Desenvolva um modelo de *credit scoring* através de uma regressão logística.
#
# - Trate valores missings e outliers
# - Trate 'zeros estruturais'
# - Faça agrupamentos de categorias conforme vimos em aula
# - Proponha uma equação preditiva para 'mau'
# - Caso hajam categorias não significantes, justifique
#
# #### Preparação do Modelo
#
# - Outliers e zeros estruturais estavam causando problemas na análise descritiva e já foram tratados.
#
# - Além disso, todas as variáveis categóricas acabaram por serem descartadas por terem IV muito baixo. Por isso não faz sentido unir categorias.
#
# - Apenas a variável *tempo_emprego* possui valores missing. Descomente o código abaixo se for testar uma regressão com ela inclusa.

# %%
#df.dropna(inplace=True)
#df_test.dropna(inplace=True)

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
#O StatsModels não aceita trabalhar com variável resposta tipo bool
df['mau'] = df.mau.astype('int8')
df_test['mau'] = df_test.mau.astype('int8')

# %% [markdown]
# Abaixo, treinamos o modelo. Das variáveis avaliadas, a única que é significativa é a renda. Além disso, separá-la em *renda_safra* e *delta_renda* parece não melhorar significativamente o modelo. Experimente fazer essas mudanças para confirmar isso na avaliação do modelo.

# %%
vars = ['renda']
formula = f'mau ~ {"+".join(vars)}'
reg = smf.glm(formula, df, family=sm.families.Binomial()).fit()

# %%
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    mau   No. Observations:               600000
# Model:                            GLM   Df Residuals:                   599998
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.2028e+05
# Date:                Wed, 06 Sep 2023   Deviance:                   2.4055e+05
# Time:                        15:35:59   Pearson chi2:                 5.97e+05
# No. Iterations:                     7   Pseudo R-squ. (CS):            0.05719
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.9239      0.049    121.382      0.000       5.828       6.020
# renda         -0.9908      0.006   -169.858      0.000      -1.002      -0.979
# ==============================================================================
# """

# %% [markdown]
# Na célula abaixo, vamos relembrar a fórmula da regressão logística para inserir os coeficientes do nosso modelo:

# %% [markdown]
# $log(odds_{mau}) = A + B*log(renda) = \mu$
#
# $odds_{mau} = e^{\mu}$
#
# $\frac{P_{mau}}{1 - P_{mau}} = e^{\mu}$
#
# ${P_{mau}} = \frac{1}{{e^{-\mu}} + 1}$

# %% [markdown]
# Com isso, podemos deduzir a equação final:
#
# ${P_{mau}} = \frac{1}{{e^{-A - B*log(renda)}} + 1} =>
# {P_{mau}} = \frac{1}{({e^{-A} *e^{-B*log(renda)}}) + 1} =>
# {P_{mau}} = \frac{1}{({e^{-A} *{e^{log(renda)}}^{-B}}) + 1} =>
# {P_{mau}} = \frac{1}{({e^{-A} * {renda}^{-B}}) + 1}$
#
# Ou seja:
#
# ${P_{mau}} = \frac{1}{{e^{0.9908*log(renda) -5.9441}} + 1}$
# ou
# ${P_{mau}} = \frac{1}{({e^{-5.9441} * {renda}^{0.9935}}) + 1}$

# %% [markdown]
# ## Avaliação do modelo
#
# Avalie o poder discriminante do modelo pelo menos avaliando acurácia, KS e Gini.
#
# Avalie estas métricas nas bases de desenvolvimento e *out of time*.

# %%
from sklearn import metrics
from scipy.stats import ks_2samp
from scipy.stats import t

# %%
def model_stats(df, reg):
    df['pred'] = reg.predict(df)

    acc = metrics.accuracy_score(df.mau == 1, df.pred >= .5)

    fpr, tpr, thresholds = metrics.roc_curve(df.mau, df.pred)
    auc = metrics.auc(fpr, tpr)

    gini = 2*auc - 1

    true_pred_test = df.loc[df.mau == 1, 'pred'] 
    false_pred_test = df.loc[df.mau == 0, 'pred']
    ks = ks_2samp(true_pred_test, false_pred_test).statistic

    return acc, auc, gini, ks

# %% [markdown]
# #### Base de treino

# %%
acc, auc, gini, ks = model_stats(df, reg)

print(f'Treino:\nPct. Bom:{1 - df.mau.mean(): .2%}\nAcurácia: {acc:.2%} \nAUC: {auc:.2%} \nGINI: {gini:.2%}\nKS: {ks:.2%}')
# Out:
# Treino:
# Pct. Bom: 93.89%
# Acurácia: 93.91%
# AUC: 77.01%
# GINI: 54.02%
# KS: 39.86%

# %% [markdown]
# #### Base de testes

# %%
acc, auc, gini, ks = model_stats(df_test, reg)

print(f'Teste:\nPct. Bom:{1 - df_test.mau.mean(): .2%}\nAcurácia: {acc:.2%} \nAUC: {auc:.2%} \nGINI: {gini:.2%}\nKS: {ks:.2%}')
# Out:
# Teste:
# Pct. Bom: 85.33%
# Acurácia: 85.48%
# AUC: 73.91%
# GINI: 47.81%
# KS: 34.68%

# %% [markdown]
# ## Conclusão
#
# Para um modelo com apenas uma variável o nosso até que dá uma classificação de clientes razoável. Porém, tem muito espaço para melhorias, já que aproveitamos apenas uma variável de dataset fornecido, que não contém dados com relação à pontuação nos birôs de crédito e hábitos de consumo, por exemplo.

# %% [markdown]
# # Módulo 38

# %% [markdown]
# # a - Criar um pipeline utilizando o sklearn pipeline para o preprocessamento
# ## Pré processamento
# ### Substituição de nulos (nans)
#
# Existe nulos na base? é dado numérico ou categórico? qual o valor de substituição? média? valor mais frequente? etc

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import FunctionTransformer, StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.decomposition import PCA

# %%
log_renda = ColumnTransformer([('log_renda', FunctionTransformer(np.log), ['renda'])], remainder='passthrough')

# %%
fillna = SimpleImputer(strategy='mean')

# %% [markdown]
# ### Remoção de outliers
#
# Como identificar outlier? Substituir o outlier por algum valor? Remover a linha?

# %%
limita_outliers = ColumnTransformer(
    [
        ('qtd_filhos', FunctionTransformer(np.clip, kw_args={'a_max': 3}), ['qtd_filhos']),
        ('qtd_pessoas', FunctionTransformer(np.clip, kw_args={'a_max': 5}), ['qt_pessoas_residencia'])
    ], 
    remainder='passthrough')

# %% [markdown]
# ### Seleção de variáveis
#
# Qual tipo de técnica? Boruta? Feature importance?

# %%
seletor = SelectFromModel(LogisticRegression())

# %%
vars_num = metadados[metadados.numeric].index
vars_cat = metadados[~metadados.numeric].index

# %% [markdown]
# ### Redução de dimensionalidade (PCA)
#
# Aplicar PCA para reduzir a dimensionalidade para 5

# %%
pca = PCA(n_components=5)

# %% [markdown]
# ### Criação de dummies
#
# Aplicar o get_dummies() ou onehotencoder() para transformar colunas catégoricas do dataframe em colunas de 0 e 1.
# - sexo
# - posse_de_veiculo
# - posse_de_imovel
# - tipo_renda
# - educacao
# - estado_civil
# - tipo_residencia

# %%
dummies_scaling = ColumnTransformer([
    ('one_hot', OneHotEncoder(), vars_cat),
    ('std_scaler', StandardScaler(), vars_num)
])

# %% [markdown]
# ### Pipeline
#
# Crie um pipeline contendo essas funções.
#
# preprocessamento()
# - substituicao de nulos
# - remoção outliers
# - PCA
# - Criação de dummy de pelo menos 1 variável (posse_de_veiculo)

# %%
pipeline = Pipeline([
    ('log_renda', log_renda),
    ('limita_outliers', limita_outliers),
    ('fillna', fillna),
    ('dummies_scaling', dummies_scaling),
    ('seletor', seletor),
    ('pca', pca)
])

# %% [markdown]
# # b - Pycaret na base de dados
#
# Utilize o pycaret para pre processar os dados e rodar o modelo **lightgbm**. Faça todos os passos a passos da aula e gere os gráficos finais. E o pipeline de toda a transformação.

# %%
df = pd.read_feather('credit_scoring.ftr').dropna()
df['safra'] = (df['data_ref'].dt.year - min(df['data_ref'].dt.year))*12 + df['data_ref'].dt.month
df = df.reindex(columns=['renda'] + [col for col in df.columns if col != 'renda'])

# %% [markdown]
# Note que resolvi remover os valores nulos fora do Pycaret porque a opção *numeric_imputation='drop'* estava dando problema na hora de gerar previsões.

# %%
df_test = df[df.safra > 12]
df_train = df[df.safra <= 12]

# %%
from pycaret.classification import *

exp = setup(
    data=df_train.sample(frac=0.1), 
    target='mau',
    numeric_imputation='mean',
    ignore_features=['index', 'data_ref', 'safra'],
    max_encoding_ohe=-1,
    remove_outliers=True,
    outliers_method='lof',
    pca=True,
    pca_components=5,
    normalize=True,
    feature_selection=False,
    feature_selection_method='classic',
    custom_pipeline=Pipeline([('log_renda', log_renda)]),
    custom_pipeline_position=0,
    fold_strategy='timeseries',
    fold=5,
)
# Out:
# <style type="text/css">
# #T_6950d_row11_col1, #T_6950d_row17_col1, #T_6950d_row19_col1, #T_6950d_row21_col1, #T_6950d_row24_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6950d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6950d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6950d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6950d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6950d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6950d_row0_col1" class="data row0 col1" >2783</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6950d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6950d_row1_col1" class="data row1 col1" >mau</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6950d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6950d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6950d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_6950d_row3_col1" class="data row3 col1" >(49912, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6950d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_6950d_row4_col1" class="data row4 col1" >(48165, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6950d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_6950d_row5_col1" class="data row5 col1" >(33191, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6950d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_6950d_row6_col1" class="data row6 col1" >(14974, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6950d_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_6950d_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6950d_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_6950d_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6950d_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_6950d_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6950d_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_6950d_row10_col1" class="data row10 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6950d_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_6950d_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6950d_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_6950d_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6950d_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_6950d_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6950d_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_6950d_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6950d_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_6950d_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6950d_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_6950d_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6950d_row17_col0" class="data row17 col0" >Remove outliers</td>
#       <td id="T_6950d_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6950d_row18_col0" class="data row18 col0" >Outliers threshold</td>
#       <td id="T_6950d_row18_col1" class="data row18 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6950d_row19_col0" class="data row19 col0" >Normalize</td>
#       <td id="T_6950d_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_6950d_row20_col0" class="data row20 col0" >Normalize method</td>
#       <td id="T_6950d_row20_col1" class="data row20 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_6950d_row21_col0" class="data row21 col0" >PCA</td>
#       <td id="T_6950d_row21_col1" class="data row21 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_6950d_row22_col0" class="data row22 col0" >PCA method</td>
#       <td id="T_6950d_row22_col1" class="data row22 col1" >linear</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_6950d_row23_col0" class="data row23 col0" >PCA components</td>
#       <td id="T_6950d_row23_col1" class="data row23 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_6950d_row24_col0" class="data row24 col0" >Custom pipeline</td>
#       <td id="T_6950d_row24_col1" class="data row24 col1" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_6950d_row25_col0" class="data row25 col0" >Fold Generator</td>
#       <td id="T_6950d_row25_col1" class="data row25 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_6950d_row26_col0" class="data row26 col0" >Fold Number</td>
#       <td id="T_6950d_row26_col1" class="data row26 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_6950d_row27_col0" class="data row27 col0" >CPU Jobs</td>
#       <td id="T_6950d_row27_col1" class="data row27 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_6950d_row28_col0" class="data row28 col0" >Use GPU</td>
#       <td id="T_6950d_row28_col1" class="data row28 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_6950d_row29_col0" class="data row29 col0" >Log Experiment</td>
#       <td id="T_6950d_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6950d_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_6950d_row30_col0" class="data row30 col0" >Experiment Name</td>
#       <td id="T_6950d_row30_col1" class="data row

# %%
clf = create_model('lightgbm', min_data_in_leaf=20)
# Out:
# <style type="text/css">
# #T_3db08_row5_col0, #T_3db08_row5_col1, #T_3db08_row5_col2, #T_3db08_row5_col3, #T_3db08_row5_col4, #T_3db08_row5_col5, #T_3db08_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3db08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3db08_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3db08_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3db08_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3db08_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3db08_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3db08_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3db08_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3db08_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3db08_row0_col0" class="data row0 col0" >0.9392</td>
#       <td id="T_3db08_row0_col1" class="data row0 col1" >0.6478</td>
#       <td id="T_3db08_row0_col2" class="data row0 col2" >0.0091</td>
#       <td id="T_3db08_row0_col3" class="data row0 col3" >0.0938</td>
#       <td id="T_3db08_row0_col4" class="data row0 col4" >0.0167</td>
#       <td id="T_3db08_row0_col5" class="data row0 col5" >0.0067</td>
#       <td id="T_3db08_row0_col6" class="data row0 col6" >0.0121</td>
#     </tr>
#     <tr>
#       <th id="T_3db08_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3db08_row1_col0" class="data row1 col0" >0.9383</td>
#       <td id="T_3db08_row1_col1" class="data row1 col1" >0.6638</td>
#       <td id="T_3db08_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_3db08_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_3db08_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_3db08_row1_col5" class="data row1 col5" >-0.0040</td>
#       <td id="T_3db08_row1_col6" class="data row1 col6" >-0.0114</td>
#     </tr>
#     <tr>
#       <th id="T_3db08_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3db08_row2_col0" class="data row2 col0" >0.9396</td>
#       <td id="T_3db08_row2_col1" class="data row2 col1" >0.6753</td>
#       <td id="T_3db08_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_3db08_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_3db08_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_3db08_row2_col5" class="data row2 col5" >-0.0033</td>
#       <td id="T_3db08_row2_col6" class="data row2 col6" >-0.0104</td>
#     </tr>
#     <tr>
#       <th id="T_3db08_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3db08_row3_col0" class="data row3 col0" >0.9339</td>
#       <td id="T_3db08_row3_col1" class="data row3 col1" >0.7230</td>
#       <td id="T_3db08_row3_col2" class="data row3 col2" >0.0052</td>
#       <td id="T_3db08_row3_col3" class="data row3 col3" >0.2857</td>
#       <td id="T_3db08_row3_col4" class="data row3 col4" >0.0103</td>
#       <td id="T_3db08_row3_col5" class="data row3 col5" >0.0079</td>
#       <td id="T_3db08_row3_col6" class="data row3 col6" >0.0308</td>
#     </tr>
#     <tr>
#       <th id="T_3db08_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3db08_row4_col0" class="data row4 col0" >0.9368</td>
#       <td id="T_3db08_row4_col1" class="data row4 col1" >0.6973</td>
#       <td id="T_3db08_row4_col2" class="data row4 col2" >0.0163</td>
#       <td id="T_3db08_row4_col3" class="data row4 col3" >0.4615</td>
#       <td id="T_3db08_row4_col4" class="data row4 col4" >0.0316</td>
#       <td id="T_3db08_row4_col5" class="data row4 col5" >0.0274</td>
#       <td id="T_3db08_row4_col6" class="data row4 col6" >0.0776</td>
#     </tr>
#     <tr>
#       <th id="T_3db08_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_3db08_row5_col0" class="data row5 col0" >0.9376</td>
#       <td id="T_3db08_row5_col1" class="data row5 col1" >0.6814</td>
#       <td id="T_3db08_row5_col2" class="data row5 col2" >0.0061</td>
#       <td id="T_3db08_row5_col3" class="data row5 col3" >0.1682</td>
#       <td id="T_3db08_row5_col4" class="data row5 col4" >0.0117</td>
#       <td id="T_3db08_row5_col5" class="data row5 col5" >0.0069</td>
#       <td id="T_3db08_row5_col6" class="data row5 col6" >0.0197</td>
#     </tr>
#     <tr>
#       <th id="T_3db08_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_3db08_row6_col0" class="data row6 col0" >0.0021</td>
#       <td id="T_3db08_row6_col1" class="data row6 col1" >0.0263</td>
#       <td id="T_3db08_row6_col2" class="data row6 col2" >0.0062</td>
#       <td id="T_3db08_row6_col3" class="data row6 col3" >0.1800</td>
#       <td id="T_3db08_row6_col4" class="data row6 col4" >0.0118</td>
#       <td id="T_3db08_row6_col5" class="data row6 col5" >0.0114</td>
#       <td id="T_3db08_row6_col6" class="data row6 col6" >0.0329</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Para ajustar os hiperparâmetros e melhorar o modelo, descomente a segunda linha abaixo. Note que é uma operação demorada!

# %%
tuned_clf = clf
#tuned_clf = tune_model(clf, fold=3)

# %%
plot_model(tuned_clf, 'auc')

# %%
plot_model(tuned_clf, 'ks')

# %%
plot_model(tuned_clf, 'pr')

# %%
plot_model(tuned_clf, 'feature')

# %%
plot_model(tuned_clf, 'confusion_matrix')

# %%
final_clf = finalize_model(tuned_clf)

# %%
pred_train = predict_model(final_clf)
# Out:
# <style type="text/css">
# </style>
# <table id="T_03737">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03737_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_03737_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_03737_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_03737_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_03737_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_03737_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_03737_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_03737_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03737_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03737_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_03737_row0_col1" class="data row0 col1" >0.9402</td>
#       <td id="T_03737_row0_col2" class="data row0 col2" >0.7760</td>
#       <td id="T_03737_row0_col3" class="data row0 col3" >0.0078</td>
#       <td id="T_03737_row0_col4" class="data row0 col4" >0.5833</td>
#       <td id="T_03737_row0_col5" class="data row0 col5" >0.0154</td>
#       <td id="T_03737_row0_col6" class="data row0 col6" >0.0138</td>
#       <td id="T_03737_row0_col7" class="data row0 col7" >0.0624</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20

# %%
pred_test = predict_model(final_clf, data=df_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7a82a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a82a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7a82a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7a82a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7a82a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7a82a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7a82a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7a82a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7a82a_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a82a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a82a_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7a82a_row0_col1" class="data row0 col1" >0.8548</td>
#       <td id="T_7a82a_row0_col2" class="data row0 col2" >0.6937</td>
#       <td id="T_7a82a_row0_col3" class="data row0 col3" >0.0164</td>
#       <td id="T_7a82a_row0_col4" class="data row0 col4" >0.4480</td>
#       <td id="T_7a82a_row0_col5" class="data row0 col5" >0.0317</td>
#       <td id="T_7a82a_row0_col6" class="data row0 col6" >0.0217</td>
#       <td id="T_7a82a_row0_col7" class="data row0 col7" >0.0630</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20

# %%
from datetime import date
save_model(final_clf, f'final_credit_clf_ {date.today()}')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('custom_step',
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=Pipeline(memory=None,
#                                                           steps=[('log_renda',
#                                                                   ColumnTransformer(n_jobs=None,
#                                                                                     remainder='passthrough',
#                                                                                     sparse_threshold=0.3,
#                                                                                     transformer_weights=None,
#                                                                                     transformers=[('log_renda',
#                                                                                                    FunctionTransformer(accept_sparse=False,
#                                                                                                                        check_inverse=...
#                   LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                  colsample_bytree=1.0, importance_type='split',
#                                  learning_rate=0.1, max_depth=-1,
#                                  min_child_samples=20, min_child_weight=0.001,
#                                  min_data_in_leaf=20, min_split_gain=0.0,
#                                  n_estimators=100, n_jobs=-1, num_leaves=31,
#                                  objective=None, random_state=2783,
#                                  reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                                  subsample_for_bin=200000, subsample_freq=0))],
#           verbose=False),
#  'final_credit_clf_ 2023-09-06.pkl')
